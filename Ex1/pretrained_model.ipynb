# %%
#文件说明：用于pretrained model的对比实验

import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# %%
# 查看可用模型
#from mmpretrain import list_models
#list_models()

# %%
# 测试一下是否成功
#!python mmpretrain/demo/image_demo.py mmpretrain/demo/demo.JPEG resnet18_8xb32_in1k

# %%
# !python mmpretrain/tools/train.py configs/resnet50_custom_1e-3.py
print("Finished!")

# %%
# !python mmpretrain/tools/train.py configs/resnext50_custom.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 18:34:13 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1917052200
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python mmpretrain/tools/train.py configs/dense161_custom.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 18:22:42 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1864607920
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python mmpretrain/tools/train.py configs/inception_v3_custom.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 18:27:44 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1637579794
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python mmpretrain/tools/train.py configs/mobilenet_v3_lager_custom.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 18:30:17 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1010251641
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...
