# %%
# 文件说明：用于frozen_stages的对比实验。
# frozen_stages=-1,
# !python mmpretrain/tools/train.py configs/resnet50_custom_0.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 17:43:56 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 777642875
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# frozen_stages=1,
# !python mmpretrain/tools/train.py configs/resnet50_custom_1.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 17:46:52 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1819131947
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# frozen_stages=2,       # 冻结主干网的层数
# !python mmpretrain/tools/train.py configs/resnet50_custom_2.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 17:49:37 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 182892735
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# frozen_stages=3,       # 冻结主干网的层数
# !python mmpretrain/tools/train.py configs/resnet50_custom_3.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 17:52:23 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 189645683
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# frozen_stages=4,       # 冻结主干网的层数
# !python mmpretrain/tools/train.py configs/resnet50_custom_4.py
print("Finished!")
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 05/14 17:54:55 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1328452298
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...
